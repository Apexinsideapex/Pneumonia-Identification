# %%
import cv2
import tensorflow as tf
import keras as k
import matplotlib.pyplot as plt
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
import os
import numpy as np

# %%
train_path = './chest_xray/chest_xray/train/'

img = cv2.imread('/home/rohit/Pneumonia-Identification/chest_xray/chest_xray/train/NORMAL/IM-0115-0001.jpeg')
img = cv2.resize(img, (500,500))
img = img/255.
#color = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
test_path = './chest_xray/chest_xray/test/'
img = cv2.imread('/home/rohit/Pneumonia-Identification/chest_xray/chest_xray/train/PNEUMONIA/person1_bacteria_1.jpeg')
img = cv2.resize(img,(500,500))
color = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img = img/255.
plt.imshow(img)

# %%
from tqdm import tqdm
labels = ['NORMAL', 'PNEUMONIA']
img_size = 500
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        print(f"Preparing data for {label}")
        for img in tqdm(os.listdir(path)):
            #count+=1
            #print(str(count))
            try:
                img_arr = cv2.imread(os.path.join(path, img))
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
train = get_data(train_path)
test = get_data(test_path)
print(f"Training has {len(train)} samples")
print(f"Test has {len(test)} samples")
# Out:
#   0%|          | 6/1342 [00:00<00:24, 55.48it/s]
# Preparing data for NORMAL
#  52%|█████▏    | 702/1342 [00:12<00:10, 58.26it/s]
# OpenCV(4.5.1) /tmp/pip-req-build-ms668fyv/opencv/modules/imgproc/src/resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# ...
#   0%|          | 19/3876 [00:00<00:20, 188.25it/s]
# Preparing data for PNEUMONIA
#  53%|█████▎    | 2038/3876 [00:11<00:11, 163.61it/s]
# OpenCV(4.5.1) /tmp/pip-req-build-ms668fyv/opencv/modules/imgproc/src/resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# 100%|██████████| 3876/3876 [00:23<00:00, 167.25it/s]
# <ipython-input-25-00c7d8d16380>:19: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(data)
# ...

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("NORMAL")
    else:
        l.append("PNEUMONIA")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /home/rohit/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[2][0])
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'NORMAL')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[-1][0])
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'PNEUMONIA')

# %%
def normalize(x):
    res = list()
    for i in x:
        res.append(i/255.)
    return np.array(res)

# %%
x_train = []
y_train = []
x_val = []
y_val = []

for feature, label in train:
  x_train.append(feature)
  y_train.append(label)

for feature, label in test:
  x_val.append(feature)
  y_val.append(label)

# Normalize the data
x_val = np.array(x_val) / 255

x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)
# Out:
#   File "<ipython-input-38-4f964105f255>", line 15
#     x_train = np.array([x for x in x_train x/255.])
#                                            ^
# SyntaxError: invalid syntax
